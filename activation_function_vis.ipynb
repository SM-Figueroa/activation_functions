# %% [markdown]
# # Activation Function Comparison and Visualization

# %%
import numpy as np
from utility import *

print("Packages Imported")
# Out:
# Packages Imported

# %%
plot_activation_functions();

# %%
# 1 million input size and 100 iterations
time_comparison(1000000, 100)
# Out:
# Average time for step: 0.647707 ms
# Average time for linear: 0.687995 ms
# Average time for ReLU: 0.704420 ms
# Average time for sigmoid: 0.713248 ms
# Average time for tanh: 0.693383 ms
